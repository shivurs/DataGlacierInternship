# %% [markdown]
# <h1>Analyzing the Data</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from datetime import datetime, date
plt.style.use('ggplot')

# %%
master = pd.read_csv('G2Mmaster.csv')

# %%
master.head()
# Out:
#    Transaction ID Date of Travel     Company        City  KM Travelled  \
# 0        10000011     2016-01-08    Pink Cab  ATLANTA GA         30.45
# 1        10351127     2018-07-21  Yellow Cab  ATLANTA GA         26.19
# 2        10412921     2018-11-23  Yellow Cab  ATLANTA GA         42.55
# 3        10000012     2016-01-06    Pink Cab  ATLANTA GA         28.62
# 4        10320494     2018-04-21  Yellow Cab  ATLANTA GA         36.38
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode Gender  Age  \
# 0         370.95      313.6350        29290         Card   Male   28
# 1         598.70      317.4228        29290         Cash   Male   28
# 2         792.05      597.4020        29290         Card   Male   28
# 3         358.52      334.8540        27703         Card   Male   27
# 4         721.10      467.1192        27703         Card   Male   27
#
#    Income (USD/Month)  Population  Users    Profit
# 0               10813      814885  24701   57.3150
# 1               10813      814885  24701  281.2772
# 2               10813      814885  24701  194.6480
# 3                9237      814885  24701   23.6660
# 4                9237      814885  24701  253.9808

# %%
master.shape
# Out:
# (359392, 15)

# %% [markdown]
# Areas of Interest:
# <ol>
#     <li>Which company services the most cab rides in total and per city/year/month?</li>
#     <li>How many customers does each company have?</li>
#     <li>What demographic is typically attracted to each company (age/gender/income)?</li>
#     <li>What percentage of cab users are customers of each company in each city?</li>
#     <li>Which company has more customer loyalty (# repeat riders/# repeat riders in consecutive years)?</li>
#     <li>What is the difference in profits per company?</li>
#     <li>What is the average profit per ride?</li>
# </ol>

# %% [markdown]
# <h2>Ride Count</h2>
# 1. Which company services the most cab rides?

# %% [markdown]
# <h3>In total</h3>

# %%
company_colors_yp = ['yellow','pink']
sns.set(style="whitegrid")
ride_count = master['Company'].value_counts()\
.plot(kind='bar', 
      color=company_colors_yp,
      title='Total Rides Serviced by Each Company')

# %%
print(master['Company'].value_counts())
# Out:
# Yellow Cab    274681
# Pink Cab       84711
# Name: Company, dtype: int64

# %% [markdown]
# <h3>By year</h3>

# %%
company_colors_py = ['pink','yellow']
master['Date of Travel'] = pd.to_datetime(master['Date of Travel'])
master['Year'] = master['Date of Travel'].dt.year
rides_per_year_company = master.groupby(['Year', 'Company']).size().unstack(fill_value=0)
rides_per_year_company.plot(kind='bar', color=company_colors_py, figsize=(10, 6))
plt.title('Rides per Year by Company')
plt.xlabel('Year')
plt.ylabel('Total Rides')
plt.legend(title='Company')
plt.show()

# %%
print(rides_per_year_company)
# Out:
# Company  Pink Cab  Yellow Cab
# Year
# 2016        25080       82239
# 2017        30321       98189
# 2018        29310       94253

# %%
percentage_change = rides_per_year_company.pct_change() * 100
percentage_change.plot(kind='bar', color=company_colors_py, figsize=(10, 6))
plt.title('Percentage Change in Rides per Year by Company')
plt.xlabel('Year')
plt.ylabel('Percentage Change')
plt.legend(title='Company')
plt.show()

# %%
print(percentage_change)
# Out:
# Company   Pink Cab  Yellow Cab
# Year
# 2016           NaN         NaN
# 2017     20.897129   19.394691
# 2018     -3.334323   -4.008596

# %% [markdown]
# <h3>By month</h3>

# %%
master['Month'] = master['Date of Travel'].dt.month
rides_per_year_month_company = master.groupby(['Year', 'Month', 'Company']).size().unstack(fill_value=0)
rides_per_year_month_company.plot(kind='bar',color=company_colors_py,figsize=(12, 6), width=0.5)
plt.title('Rides per Year and Month by Company')
plt.xlabel('Year - Month')
plt.ylabel('Total Rides')
plt.legend(title='Company')
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# <h3>By city, total</h3>

# %%
master['City'].value_counts()
# Out:
# NEW YORK NY       99885
# CHICAGO IL        56625
# LOS ANGELES CA    48033
# WASHINGTON DC     43737
# BOSTON MA         29692
# SAN DIEGO CA      20488
# SILICON VALLEY     8519
# SEATTLE WA         7997
# ATLANTA GA         7557
# DALLAS TX          7017
# MIAMI FL           6454
# AUSTIN TX          4896
# ORANGE COUNTY      3982
# DENVER CO          3825
# NASHVILLE TN       3010
# SACRAMENTO CA      2367
# PHOENIX AZ         2064
# TUCSON AZ          1931
# PITTSBURGH PA      1313
# Name: City, dtype: int64

# %%
ride_count = master.groupby(['City', 'Company']).size().unstack()
ax = ride_count.plot(kind='barh', 
                     stacked=True, 
                     title='Total Rides Serviced by Pink Cab & Yellow Cab', 
                     color=company_colors_py,
                    figsize=(10, 5))
ax.set_ylabel('City')
ax.set_xlabel('Total Rides')
plt.xticks(rotation=0)
ax.legend(title='Company')
plt.show()

# %% [markdown]
# <h3>By city, percentage</h3>

# %%
percentage_rides_per_company_city = master.groupby(['City', 'Company']).size() / master.groupby('City').size()
percentage_rides_per_company_city *= 100
percentage_rides_per_company_city = percentage_rides_per_company_city.reset_index()

pivot_table = percentage_rides_per_company_city.pivot(index='City', columns='Company', values=0)

pivot_table.plot(kind='bar', figsize=(10, 6), color=company_colors_py, stacked=True)
plt.title('Percentage of Total Rides by Company in City')
plt.xlabel('City')
plt.ylabel('Percentage of Total Rides')
plt.legend(title='Company')
plt.show()

for container in ax.containers:
    ax.bar_label(container, labels=[f'{val:.1f}%' for val in container.datavalues], 
                 label_type='center', fontsize=8, color='black')

# %%
print(percentage_rides_per_company_city)
# Out:
#               City     Company          0
# 0       ATLANTA GA    Pink Cab  23.316131
# 1       ATLANTA GA  Yellow Cab  76.683869
# 2        AUSTIN TX    Pink Cab  38.153595
# 3        AUSTIN TX  Yellow Cab  61.846405
# 4        BOSTON MA    Pink Cab  17.465984
# 5        BOSTON MA  Yellow Cab  82.534016
# 6       CHICAGO IL    Pink Cab  16.531567
# 7       CHICAGO IL  Yellow Cab  83.468433
# 8        DALLAS TX    Pink Cab  19.666524
# 9        DALLAS TX  Yellow Cab  80.333476
# 10       DENVER CO    Pink Cab  36.444444
# 11       DENVER CO  Yellow Cab  63.555556
# 12  LOS ANGELES CA    Pink Cab  41.356984
# 13  LOS ANGELES CA  Yellow Cab  58.643016
# 14        MIAMI FL    Pink Cab  31.019523
# 15        MIAMI FL  Yellow Cab  68.980477
# 16    NASHVILLE TN    Pink Cab  61.162791
# 17    NASHVILLE TN  Yellow Cab  38.837209
# 18     NEW YORK NY    Pink Cab  13.983081
# 19     NEW YORK NY  Yellow Cab  86.016919
# 20   ORANGE COUNTY    Pink Cab  37.995982
# 21   ORANGE COUNTY  Yellow Cab  62.004018
# 22      PHOENIX AZ    Pink Cab  41.860465
# 23      PHOENIX AZ  Yellow Cab  58.139535
# 24   PITTSBURGH PA    Pink Cab  51.942117
# 25   PITTSBURGH PA  Yellow Cab  48.057883
# 26   SACRAMENTO CA    Pink Cab  56.358259
# 27   SACRAMENTO CA  Yellow Cab  43.641741
# 28    SAN DIEGO CA    Pink Cab  52.089028
# 29    SAN DIEGO CA  Yellow Cab  47.910972
# 30      SEATTLE WA    Pink Cab  34.162811
# 31      SEATTLE WA  Yellow Cab  65.837189
# 32  SILICON VALLEY    Pink Cab  44.570959
# 33  SILICON VALLEY  Yellow Cab  55.429041
# 34       TUCSON AZ    Pink Cab  41.377525
# 35       TUCSON AZ  Yellow Cab  58.622475
# 36   WASHINGTON DC    Pink Cab   8.441365
# 37   WASHINGTON DC  Yellow Cab  91.558635

# %%
cab_usage_percentage = master.groupby(['City', 'Company'])['Customer ID'].count()/master.groupby('City')['Customer ID'].count()
cab_usage_percentage = cab_usage_percentage.unstack(fill_value=0) * 100

plt.figure(figsize=(12, 8))
sns.heatmap(cab_usage_percentage, cmap="YlGnBu", annot=True, fmt=".1f", cbar_kws={'label': 'Percentage of Cab Users'})
plt.title('Percentage of Cab Users by Company and City')
plt.xlabel('Company')
plt.ylabel('City')
plt.xticks(rotation=0, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Which company services the most cab rides?
# <ul><li>Yellow Cab serviced the most rides in all categories.</li><ul>

# %% [markdown]
# <h2>Customer Base</h2>
# <ol start='2'>
#     <li>How many customers does each company have?</li>
#     <li>What demographic is typically attracted to each company (age/gender/income)?</li>
#     <li>What percentage of cab users are customers of each company in each city?</li>
#     <li>Which company has more customer loyalty (repeat riders/repeat riders in consecutive years)?</li>
# </ol>

# %%
unique_customer_count_by_company = master.groupby('Company')['Customer ID'].nunique()
print(unique_customer_count_by_company)
# Out:
# Company
# Pink Cab      32330
# Yellow Cab    39896
# Name: Customer ID, dtype: int64

# %%
customer_count_by_company = master.groupby('Company')['Customer ID'].nunique()
customer_count_by_company.plot(kind='barh', color=company_colors_py, figsize=(10, 6))
plt.title('Customer Count by Company')
plt.xlabel('Number of Customers')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# Seeing that Yellow Cab has only roughly 7.5 thousand more clients, and service many more rides, it is worth comparing the number of customers to percentage of total rides.

# %%
percentage_rides_per_company_year = master.groupby(['Year', 'Company']).size() / master.groupby('Year').size()
percentage_rides_per_company_year *= 100
percentage_rides_per_company_year = percentage_rides_per_company_year.reset_index()

pivot_table = percentage_rides_per_company_year.pivot(index='Year', columns='Company', values=0)

pivot_table.plot(kind='bar', figsize=(10, 6), color=company_colors_py, stacked=True)
plt.title('Percentage of Total Rides by Company and Year')
plt.xlabel('Year')
plt.ylabel('Percentage of Total Rides')
plt.legend(title='Company')
plt.show()

for container in ax.containers:
    ax.bar_label(container, labels=[f'{val:.1f}%' for val in container.datavalues], 
                 label_type='center', fontsize=8, color='black')

# %%
print(percentage_rides_per_company_year)
# Out:
#    Year     Company          0
# 0  2016    Pink Cab  23.369580
# 1  2016  Yellow Cab  76.630420
# 2  2017    Pink Cab  23.594273
# 3  2017  Yellow Cab  76.405727
# 4  2018    Pink Cab  23.720693
# 5  2018  Yellow Cab  76.279307

# %% [markdown]
# As the plot shows, Yellow Cab services about 76% more rides per year with only about 23% more clients in their customer base.

# %%
# gender
company_colors = {'Yellow Cab': 'yellow', 'Pink Cab': 'pink'}
sns.violinplot(data=master, x='Gender', y='Age', hue='Company', 
               palette=company_colors, split=True)
plt.title('Age by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %%
grouped = master.groupby(['Gender', 'Company'])['Age']

for name, group in grouped:
    group_mean = group.mean()
    group_iqr = group.quantile(0.75) - group.quantile(0.25)
    
    print(f"Group: {name}")
    print(f"Mean: {group_mean:.2f}")
    print(f"IQR: {group_iqr:.2f}")
# Out:
# Group: ('Female', 'Pink Cab')
# Mean: 35.27
# IQR: 17.00
# Group: ('Female', 'Yellow Cab')
# Mean: 35.29
# IQR: 17.00
# Group: ('Male', 'Pink Cab')
# Mean: 35.36
# IQR: 17.00
# Group: ('Male', 'Yellow Cab')
# Mean: 35.38
# IQR: 17.00

# %%
# age
master['Age Group'] = (master['Age'] // 10) * 10
sns.violinplot(data=master, x='Age Group', y='Income (USD/Month)', 
               hue='Company', palette=company_colors, split=True)
plt.title('Income by Age Group')
plt.xlabel('Age Group by Decade')
plt.ylabel('Monthly Income')
plt.show()

# %%
grouped = master.groupby(['Age Group', 'Company'])['Income (USD/Month)']

for name, group in grouped:
    group_mean = group.mean()
    group_iqr = group.quantile(0.75) - group.quantile(0.25)
    
    print(f"Group: {name}")
    print(f"Mean: {group_mean:.2f}")
    print(f"IQR: {group_iqr:.2f}")
# Out:
# Group: (10, 'Pink Cab')
# Mean: 14745.09
# IQR: 12180.00
# Group: (10, 'Yellow Cab')
# Mean: 14777.27
# IQR: 12572.00
# Group: (20, 'Pink Cab')
# Mean: 15057.09
# IQR: 12678.50
# Group: (20, 'Yellow Cab')
# Mean: 15099.84
# IQR: 12576.00
# Group: (30, 'Pink Cab')
# Mean: 14965.15
# IQR: 12829.00
# Group: (30, 'Yellow Cab')
# Mean: 14992.02
# IQR: 12610.00
# Group: (40, 'Pink Cab')
# Mean: 15118.01
# IQR: 12777.00
# Group: (40, 'Yellow Cab')
# Mean: 15020.26
# IQR: 12577.50
# Group: (50, 'Pink Cab')
# Mean: 15539.68
# IQR: 12666.75
# Group: (50, 'Yellow Cab')
# Mean: 15430.98
# IQR: 12616.00
# Group: (60, 'Pink Cab')
# Mean: 14930.23
# IQR: 12675.00
# Group: (60, 'Yellow Cab')
# Mean: 14701.42
# IQR: 12728.00

# %%
# income
sns.violinplot(data=master, x='Income (USD/Month)', y='Gender', 
               hue='Company', palette=company_colors, split=True)
plt.title('Gender by Income')
plt.xlabel('Monthly Income')
plt.ylabel('Gender')
# Out:
# Text(0, 0.5, 'Gender')

# %% [markdown]
# Based on the above violin plots, it is visually apparent that the demographics of both companies are quite comparable in all three categories of age, gender, and monthly income.

# %%
customer_counts = master.groupby(['Company', 'Customer ID']).size()
repeat_counts = customer_counts.groupby('Company').apply(lambda x: (x > 1).sum())

sns.barplot(data=repeat_counts.reset_index(name='Repeat Customers'), 
            x='Company', y='Repeat Customers', 
            palette=company_colors)
plt.title('Total Number of Repeat Customers by Company')
plt.xlabel('Company')
plt.ylabel('Total Number of Repeat Customers')

plt.tight_layout()
plt.show()

# %%
repeat_counts = master[master.duplicated(subset=['Customer ID', 'Company', 'Year'], 
                                         keep='first')].groupby(['Company', 'Year'])['Customer ID'].nunique()
repeat_counts = repeat_counts.reset_index(name='Repeat Customers')

sns.barplot(data=repeat_counts, x='Year', y='Repeat Customers', 
            hue='Company', palette=company_colors)
plt.title('Total Number of Repeat Customers by Year and Company')
plt.xlabel('Year')
plt.ylabel('Total Number of Repeat Customers')
plt.legend(title='Company')

plt.tight_layout()
plt.show()

# %% [markdown]
# It is already known that Yellow Cab has more total customers, so it is not entirely helpful to see a simple total of repeat customers; a percentage based on each company's total customers individually would be more actionable.

# %%
total_customers = master.groupby(['Company', 'Year'])['Customer ID'].nunique()

repeat_counts = master[master.duplicated(subset=['Customer ID', 'Company', 'Year'], 
                                         keep='first')].groupby(['Company', 'Year'])['Customer ID'].nunique()

repeat_percentages = (repeat_counts / total_customers) * 100

repeat_data = pd.DataFrame({'Company': repeat_percentages.index.get_level_values('Company'),
                            'Year': repeat_percentages.index.get_level_values('Year'),
                            'Repeat Percentage': repeat_percentages.values})

sns.barplot(data=repeat_data, x='Year', y='Repeat Percentage', 
            hue='Company', palette=company_colors)
plt.title('Percentage of Repeat Customers by Year and Company')
plt.xlabel('Year')
plt.ylabel('Percentage of Repeat Customers')
plt.legend(title='Company', loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Profits</h2>
# <ol start='6'>
#     <li>What is the difference in profits per company?</li>
#     <li>What is the average profit per ride?</li>
# </ol>

# %%
# total profits
grouped_data = master.groupby(['Company', 'Year'])['Profit'].sum().reset_index()

pivot_data = grouped_data.pivot(index='Year', columns='Company', values='Profit')

pivot_data.plot(kind='bar', color=company_colors, stacked=False)
plt.xlabel('Year')
plt.ylabel('Total Profit')
plt.title('Total Profits of Yellow Cab and Pink Cab by Year')
plt.xticks(rotation=0)
plt.tight_layout()
step_size = 2000000
plt.yticks(np.arange(0, max(pivot_data.sum(axis=1)) + step_size, step_size))
plt.ticklabel_format(style='plain', axis='y')

plt.show()

# %%
print(grouped_data)
# Out:
#       Company  Year        Profit
# 0    Pink Cab  2016  1.713511e+06
# 1    Pink Cab  2017  2.033655e+06
# 2    Pink Cab  2018  1.560162e+06
# 3  Yellow Cab  2016  1.392700e+07
# 4  Yellow Cab  2017  1.657598e+07
# 5  Yellow Cab  2018  1.351740e+07

# %%
# average profits
average_profit = grouped_data.groupby('Company')['Profit'].mean()
print(average_profit)
# Out:
# Company
# Pink Cab      1.769109e+06
# Yellow Cab    1.467346e+07
# Name: Profit, dtype: float64

# %%
# percent change in profit per year
percent_changes = pivot_data.pct_change() * 100

percent_changes.plot(kind='bar', color=[company_colors[col] for col in percent_changes.columns])
plt.xlabel('Year')
plt.ylabel('Percent Change (%)')
plt.title('Percent Increase/Decrease of Profits for Yellow Cab and Pink Cab')
plt.xticks(rotation=0)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')  # Add a horizontal line at 0%
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
print(percent_changes)
# Out:
# Company   Pink Cab  Yellow Cab
# Year
# 2016           NaN         NaN
# 2017     18.683489   19.020488
# 2018    -23.282845  -18.451872

# %%
average_profit_per_ride = master.groupby('Company')['Profit'].mean()

average_profit_per_ride.plot(kind='bar', color=company_colors_py)
plt.xlabel('Company')
plt.ylabel('Average Profit per Ride')
plt.title('Average Profit per Ride by Company')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
print(average_profit_per_ride)
# Out:
# Company
# Pink Cab       62.652174
# Yellow Cab    160.259986
# Name: Profit, dtype: float64

# %%
average_cost_per_ride = master.groupby('Company')['Cost of Trip'].mean()

average_cost_per_ride.plot(kind='bar', color=company_colors_py)
plt.xlabel('Company')
plt.ylabel('Average Cost per Ride')
plt.title('Average Cost per Ride by Company')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
print(average_cost_per_ride)
# Out:
# Company
# Pink Cab      248.148682
# Yellow Cab    297.922004
# Name: Cost of Trip, dtype: float64

# %%
sns.pairplot(master,
            vars=['Price Charged',
                  'Cost of Trip',
                  'KM Travelled'],
            hue='Company')
plt.show()

# %%
corr = master[['Price Charged',
                  'Cost of Trip',
                  'KM Travelled']].corr()
corr
# Out:
#                Price Charged  Cost of Trip  KM Travelled
# Price Charged       1.000000      0.859812      0.835753
# Cost of Trip        0.859812      1.000000      0.981848
# KM Travelled        0.835753      0.981848      1.000000

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# <h2>Takeaways</h2>
# Yellow Cab has outshined Pink Cab in nearly every category and datapoint comparison.
# <ul>
#     <li>Rides: Yellow Cab has provided more service overall.</li>
#     <li>Customers: Yellow Cab has more customers in total and more repeat customers.</li>
#     <li>Profit: Yellow Cab has more profits in total and on average.</li>
# </ul>
#
# <h2>Recommendation</h2>
# Based on this analysis, the recommendation is to invest in Yellow Cab.
